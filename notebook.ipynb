# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('student_habits_performance.csv')

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %%
df.shape
# Out:
# (1000, 16)

# %%
sns.set(style="whitegrid")

# %%
df.isna().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# study_hours_per_day              0
# social_media_hours               0
# netflix_hours                    0
# part_time_job                    0
# attendance_percentage            0
# sleep_hours                      0
# diet_quality                     0
# exercise_frequency               0
# parental_education_level         0
# internet_quality                 0
# mental_health_rating             0
# extracurricular_participation    0
# exam_score                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.200000     6.500000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            909.000000  909.000000
# mean               5.466447   69.558196
# std                2.857525   16.929436
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.400000
# 75%                8.000000   81.300000
# max               10.000000  100.000000

# %%
df.describe(include=['object'])
# Out:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1000   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %%
category_cols=["gender","part_time_job","diet_quality","parental_education_level","internet_quality","extracurricular_participation"]

# %%
for col in category_cols:
    print(f"Value Counts for {col}: \n {df[col].value_counts()}")
# Out:
# Value Counts for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# Value Counts for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# Value Counts for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# Value Counts for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# Value Counts for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# Value Counts for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
for col in category_cols:
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features=['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for feature in num_features:
    sns.scatterplot(data = df, x=feature, y="exam_score")
    plt.title(f'Exam Score vs {feature}')
    plt.show()

# %%
for col in category_cols:
    sns.boxplot(data=df, x=col, y='exam_score')
    plt.title(f'Exam Score by {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
features=["study_hours_per_day", "attendance_percentage", "mental_health_rating","sleep_hours","part_time_job"]

# %%
target="exam_score"

# %%
df_model=df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# 1            4.6            No       100.0
# 2            8.0            No        34.3
# 3            9.2            No        26.8
# 4            4.9            No        66.4
# ..           ...           ...         ...
# 995          7.5            No        76.1
# 996          6.8           Yes        65.9
# 997          6.5            No        64.4
# 998          7.6           Yes        69.7
# 999          7.1            No        74.9
#
# [909 rows x 6 columns]

# %%
le=LabelEncoder()

# %%
df_model["part_time_job"]=le.fit_transform(df_model['part_time_job'])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# 1            4.6              0       100.0
# 2            8.0              0        34.3
# 3            9.2              0        26.8
# 4            4.9              0        66.4
# ..           ...            ...         ...
# 995          7.5              0        76.1
# 996          6.8              1        65.9
# 997          6.5              0        64.4
# 998          7.6              1        69.7
# 999          7.1              0        74.9
#
# [909 rows x 6 columns]

# %%
X=df_model[features]
y=df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
len(y_train)
# Out:
# 727

# %%
models={
    "LinearRegression": {
        "model": LinearRegression(),
        "params": {}
    },
    "DecisionTree": {
        "model": DecisionTreeRegressor(),
        "params": {"max_depth": [3,5,10],"min_samples_split":[2,5]}
    },
    "RandomForest": {
        "model": RandomForestRegressor(),
        "params": {"n_estimators": [50,100], "max_depth": [5,10]}
    }
}

# %%
best_models=[]

# %%
for name,config in models.items():
    print(f"Training {name}")

    grid=GridSearchCV(config['model'], config['params'], cv=5, scoring='neg_mean_squared_error')
    grid.fit(X_train, y_train)

    y_pred=grid.predict(X_test)
    rmse=np.sqrt(mean_squared_error(y_test, y_pred))
    r2= r2_score(y_test, y_pred)

    best_models.append({
        "model": name,
        "best_params": grid.best_params_,
        "rmse": rmse,
        "r2_score": r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': 7.424942038874962,
#   'r2_score': 0.8108962375783496},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 5},
#   'rmse': 8.290362458853629,
#   'r2_score': 0.7642449136985162},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 10, 'n_estimators': 100},
#   'rmse': 7.880392966284986,
#   'r2_score': 0.7869851976430583}]

# %%
results_df=pd.DataFrame(best_models)

# %%
results_df.sort_values(by='rmse')
# Out:
#               model                               best_params      rmse  \
# 0  LinearRegression                                        {}  7.424942
# 2      RandomForest    {'max_depth': 10, 'n_estimators': 100}  7.880393
# 1      DecisionTree  {'max_depth': 5, 'min_samples_split': 5}  8.290362
#
#    r2_score
# 0  0.810896
# 2  0.786985
# 1  0.764245

# %%
import joblib

best_row=results_df.sort_values(by='rmse').iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# rmse                   7.424942
# r2_score               0.810896
# Name: 0, dtype: object

# %%
best_model_name=best_row['model']

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config=models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model=best_model_config['model'].set_params(**best_row['best_params'])

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
final_model.predict(X_test)
# Out:
# array([ 87.78875123,  86.30137744,  59.03104355,  50.4895758 ,
#         65.68154311,  47.41966756,  42.98530424,  61.60372745,
#         54.8674567 ,  65.81297953,  45.77718556,  83.76282292,
#         81.60879862,  66.70036983,  64.05479374,  94.28634195,
#         95.61742841,  63.3153885 ,  60.61304698,  59.80546684,
#         81.11484092,  89.1592608 ,  66.09964476,  72.4395309 ,
#         64.21237739,  71.76290348,  48.13871672,  68.22890505,
#         72.17523691,  40.74930647,  73.06952749,  74.97479241,
#         74.30904731,  66.31366546,  63.8141856 ,  67.28188611,
#         59.86149389,  67.50594954,  70.31885498,  61.37643194,
#         47.74082004,  76.23992153,  79.98469099,  69.19275373,
#         56.4052808 ,  79.30877704,  84.71786767,  51.1813487 ,
#         71.42430502,  77.48107335,  54.84649087,  77.30359466,
#         57.44638498,  84.1404169 ,  74.89289694,  81.86159654,
#         82.47701204,  99.38541188,  52.84828921,  55.87543662,
#         83.12680365, 103.39848608,  62.67344973,  47.5688949 ,
#         53.68824906,  76.62284649,  34.07217639,  57.67033365,
#         66.72764266,  86.33867011,  73.19341212,  84.00104813,
#         76.75958523,  85.15391158, 102.83147733,  88.10129326,
#         74.78817074,  66.22583241,  37.5268067 ,  91.99423492,
#         57.8301418 , 105.61559246,  87.76819727,  75.61018805,
#         62.07233324,  60.51626214,  64.51168013, 100.00884675,
#         97.04729563,  57.60239563,  66.25211042,  54.52840609,
#         47.52966995,  67.06989821,  66.36405947,  76.55263164,
#         36.59323364,  74.5771561 ,  64.9023466 ,  77.1562697 ,
#         83.47702877,  60.08723101,  63.04843369,  73.50744843,
#         74.18329974,  50.74268471,  78.30936564,  89.92801771,
#         74.53698275,  35.38057943,  82.34026337,  62.79878985,
#         70.64707086,  66.16326409,  46.89711801,  79.75220639,
#         72.25779551,  68.38334944,  87.69201972,  87.66820478,
#         47.10026421,  72.22004207,  76.84828965,  80.08715057,
#         81.64018775,  86.19114402,  60.6209758 ,  76.9384696 ,
#         79.7245903 ,  63.74810186,  53.35891573,  75.58766803,
#         86.17103408,  45.36227919,  66.75598134,  63.63790671,
#        116.48483776,  54.20184513, 101.60276357,  68.67649345,
#         87.05013225,  52.76981731,  62.21932629,  75.7404905 ,
#         55.50712337,  95.52324961,  92.71797491,  69.35389946,
#         33.01259124, 104.58685302,  70.32196933,  65.04552732,
#         66.57818379,  58.73592725,  55.02624368,  55.03445016,
#         70.83486134,  69.96011467,  89.69195799,  60.98129875,
#         74.54938602,  65.38478204,  73.35099897,  72.6281173 ,
#         53.7393235 ,  71.06624832,  68.39919847,  60.95454931,
#         66.0866954 ,  91.52584331,  66.55221819,  62.62439   ,
#         76.0390916 ,  61.76235132,  69.37049503,  69.09467311,
#         58.31327072, 102.62470515,  74.8589124 ,  54.27941821,
#         89.38708519,  73.63145597])

# %%
joblib.dump(final_model, 'final_student_performance_model.pkl')
# Out:
# ['final_student_performance_model.pkl']

# %%
joblib.load('final_student_performance_model.pkl').predict(X_test)
# Out:
# array([ 87.78875123,  86.30137744,  59.03104355,  50.4895758 ,
#         65.68154311,  47.41966756,  42.98530424,  61.60372745,
#         54.8674567 ,  65.81297953,  45.77718556,  83.76282292,
#         81.60879862,  66.70036983,  64.05479374,  94.28634195,
#         95.61742841,  63.3153885 ,  60.61304698,  59.80546684,
#         81.11484092,  89.1592608 ,  66.09964476,  72.4395309 ,
#         64.21237739,  71.76290348,  48.13871672,  68.22890505,
#         72.17523691,  40.74930647,  73.06952749,  74.97479241,
#         74.30904731,  66.31366546,  63.8141856 ,  67.28188611,
#         59.86149389,  67.50594954,  70.31885498,  61.37643194,
#         47.74082004,  76.23992153,  79.98469099,  69.19275373,
#         56.4052808 ,  79.30877704,  84.71786767,  51.1813487 ,
#         71.42430502,  77.48107335,  54.84649087,  77.30359466,
#         57.44638498,  84.1404169 ,  74.89289694,  81.86159654,
#         82.47701204,  99.38541188,  52.84828921,  55.87543662,
#         83.12680365, 103.39848608,  62.67344973,  47.5688949 ,
#         53.68824906,  76.62284649,  34.07217639,  57.67033365,
#         66.72764266,  86.33867011,  73.19341212,  84.00104813,
#         76.75958523,  85.15391158, 102.83147733,  88.10129326,
#         74.78817074,  66.22583241,  37.5268067 ,  91.99423492,
#         57.8301418 , 105.61559246,  87.76819727,  75.61018805,
#         62.07233324,  60.51626214,  64.51168013, 100.00884675,
#         97.04729563,  57.60239563,  66.25211042,  54.52840609,
#         47.52966995,  67.06989821,  66.36405947,  76.55263164,
#         36.59323364,  74.5771561 ,  64.9023466 ,  77.1562697 ,
#         83.47702877,  60.08723101,  63.04843369,  73.50744843,
#         74.18329974,  50.74268471,  78.30936564,  89.92801771,
#         74.53698275,  35.38057943,  82.34026337,  62.79878985,
#         70.64707086,  66.16326409,  46.89711801,  79.75220639,
#         72.25779551,  68.38334944,  87.69201972,  87.66820478,
#         47.10026421,  72.22004207,  76.84828965,  80.08715057,
#         81.64018775,  86.19114402,  60.6209758 ,  76.9384696 ,
#         79.7245903 ,  63.74810186,  53.35891573,  75.58766803,
#         86.17103408,  45.36227919,  66.75598134,  63.63790671,
#        116.48483776,  54.20184513, 101.60276357,  68.67649345,
#         87.05013225,  52.76981731,  62.21932629,  75.7404905 ,
#         55.50712337,  95.52324961,  92.71797491,  69.35389946,
#         33.01259124, 104.58685302,  70.32196933,  65.04552732,
#         66.57818379,  58.73592725,  55.02624368,  55.03445016,
#         70.83486134,  69.96011467,  89.69195799,  60.98129875,
#         74.54938602,  65.38478204,  73.35099897,  72.6281173 ,
#         53.7393235 ,  71.06624832,  68.39919847,  60.95454931,
#         66.0866954 ,  91.52584331,  66.55221819,  62.62439   ,
#         76.0390916 ,  61.76235132,  69.37049503,  69.09467311,
#         58.31327072, 102.62470515,  74.8589124 ,  54.27941821,
#         89.38708519,  73.63145597])
